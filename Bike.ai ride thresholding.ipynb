# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
print(os.listdir())
# Out:
# ['my_tests', 'postgresql', 'Screen Shot 2019-10-30 at 9.53.32 PM.png', 'Screen Shot 2019-10-30 at 9.53.41 PM.png', '.DS_Store', 'Screen Shot 2019-10-30 at 9.53.53 PM.png', 'Screen Shot 2019-10-30 at 8.51.05 PM.png', 'Screen Shot 2019-10-30 at 10.03.38 PM.png', '.localized', 'AVAI', 'Untitled.ipynb', 'Screen Shot 2019-10-30 at 10.03.18 PM.png', 'Screen Shot 2019-10-30 at 8.51.25 PM.png', 'Assaf', 'Screen Shot 2019-10-30 at 9.53.49 PM.png', 'NewsWebsite', 'Screen Shot 2019-10-30 at 9.48.39 PM.png', 'Screen Shot 2019-10-30 at 8.51.01 PM.png', 'Screen Shot 2019-10-30 at 9.53.45 PM.png', 'Screen Shot 2019-10-30 at 9.34.25 PM.png', 'Website', 'minioprojects', 'TESTFILE.log', 'Screen Shot 2019-10-30 at 8.50.52 PM.png', 'tests', 'Screen Shot 2019-10-30 at 9.34.48 PM.png', '.jshintrc', 'transcript.pdf', 'prob8', 'Screen Shot 2019-10-30 at 9.53.24 PM.png', 'EE149', 'Screen Shot 2019-10-30 at 10.03.43 PM.png', 'Screen Shot 2019-10-30 at 9.53.36 PM.png', 'search', '.mention-bot', 'Screen Shot 2019-10-30 at 8.51.30 PM.png', 'cs186', 'Screen Shot 2019-10-30 at 9.34.53 PM.png', 'Screen Shot 2019-10-30 at 9.34.30 PM.png', 'KleinerPerkins', '.gitignore', 'sort stuff', 'temp_website', 'Screen Shot 2019-10-30 at 9.34.43 PM.png', 'need to sort stuff', '61C', '.RNN generated text Rnn size 1200 batch_size 200 num_layers 3 epoch 14.81.rtf.swp', '.github', 'hu', 'Screen Shot 2019-10-30 at 9.35.02 PM.png', 'tracking', '.ipynb_checkpoints', '.mailmap', 'Screen Shot 2019-10-30 at 8.51.12 PM.png', '.git', 'Screen Shot 2019-10-30 at 9.53.27 PM.png', 'Screen Shot 2019-10-30 at 8.51.36 PM.png', '.travis.yml', 'Screen Shot 2019-10-30 at 9.34.38 PM.png', 'Screen Shot 2019-10-30 at 9.34.57 PM.png', '.idea', 'facebook-arjunmishra71', 'Screen Shot 2019-10-30 at 9.34.34 PM.png']

# %%
time = []
x = []
with open ("TESTFILE.LOG") as file:
    for index,line in enumerate(file.readlines()):
        if len(line.split(",")[0][2:][:-1]) > 10 or line.split(",")[0][3:][0] == "-":
            continue
        x.append(float(line.split(",")[0][2:][:-1].replace(",","")))
        time.append(index)

# %%
plt.plot(time,x)
plt.xticks(np.arange(0, 240, 20.0))
plt.yticks(np.arange(min(x), max(x), 0.2))
plt.show()

# %%
import seaborn as sns
temp = pd.DataFrame(columns=['time', 'acceleration'])
temp["time"] = np.array(time)
temp["acceleration"] = np.array(x)
sns.regplot(x=temp["time"], y=temp["acceleration"])
plt.show()
